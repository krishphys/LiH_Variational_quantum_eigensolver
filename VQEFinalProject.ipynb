# %%
from qiskit import BasicAer, Aer, IBMQ
from qiskit.aqua import QuantumInstance, aqua_globals
from qiskit.aqua.algorithms import VQE, NumPyEigensolver
from qiskit.aqua.components.initial_states import Zero
from qiskit.aqua.components.optimizers import COBYLA, L_BFGS_B, SLSQP, SPSA
from qiskit.aqua.components.variational_forms import RY, RYRZ, SwapRZ
from qiskit.aqua.operators import WeightedPauliOperator, Z2Symmetries
from qiskit.chemistry import FermionicOperator
from qiskit.chemistry.drivers import PySCFDriver, UnitsType
from qiskit.chemistry.components.variational_forms import UCCSD
from qiskit.chemistry.components.initial_states import HartreeFock

from qiskit.providers.aer import QasmSimulator
from qiskit.providers.aer.noise import NoiseModel
from qiskit.providers.aer.noise.errors import QuantumError, ReadoutError
from qiskit.providers.aer.noise.errors import pauli_error
from qiskit.providers.aer.noise.errors import depolarizing_error
from qiskit.providers.aer.noise.errors import thermal_relaxation_error

from qiskit.providers.aer import noise
provider = IBMQ.load_account()

import numpy as np
import matplotlib.pyplot as plt
from functools import partial

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
# Out:
# ibmqfactory.load_account:WARNING:2020-08-06 14:29:31,969: Credentials are already in use. The existing account in the session will be replaced.

# %%
# Classically solve for the lowest eigenvalue
# This is used just to compare how well you VQE approximation is performing
def exact_solver(qubitOp, shift):
    ee = NumPyEigensolver(qubitOp)
    result = ee.run()
    ref = result['eigenvalues']
    ref+= shift
    print('Reference value: {}'.format(ref))
    return ref

# %%
# Define your function for computing the qubit operations of LiH
def compute_LiH_qubitOp(map_type, inter_dist, basis='sto3g'):
    
    # Specify details of our molecule
    driver = PySCFDriver(atom='Li .0 .0 .0; H .0 .0 ' + str(inter_dist), unit=UnitsType.ANGSTROM, charge=0, spin=0, basis=basis)

    # Compute relevant 1 and 2 body integrals.
    molecule = driver.run()
    h1 = molecule.one_body_integrals
    h2 = molecule.two_body_integrals
    nuclear_repulsion_energy = molecule.nuclear_repulsion_energy
    
    num_particles = molecule.num_alpha + molecule.num_beta
    num_spin_orbitals = molecule.num_orbitals * 2
    print("HF energy: {}".format(molecule.hf_energy - molecule.nuclear_repulsion_energy))
    print("# of electrons: {}".format(num_particles))
    print("# of spin orbitals: {}".format(num_spin_orbitals))

    # Please be aware that the idx here with respective to original idx
    freeze_list = [0]
    remove_list = [-3, -2] # negative number denotes the reverse order
    
    # Prepare full idx of freeze_list and remove_list
    # Convert all negative idx to positive
    remove_list = [x % molecule.num_orbitals for x in remove_list]
    freeze_list = [x % molecule.num_orbitals for x in freeze_list]
    
    # Update the idx in remove_list of the idx after frozen, since the idx of orbitals are changed after freezing
    remove_list = [x - len(freeze_list) for x in remove_list]
    remove_list += [x + molecule.num_orbitals - len(freeze_list)  for x in remove_list]
    freeze_list += [x + molecule.num_orbitals for x in freeze_list]

    # Prepare fermionic hamiltonian with orbital freezing and eliminating, and then map to qubit hamiltonian
    # and if PARITY mapping is selected, reduction qubits
    energy_shift = 0.0
    qubit_reduction = True if map_type == 'parity' else False

    ferOp = FermionicOperator(h1=h1, h2=h2)
    if len(freeze_list) > 0:
        ferOp, energy_shift = ferOp.fermion_mode_freezing(freeze_list)
        num_spin_orbitals -= len(freeze_list)
        num_particles -= len(freeze_list)
    if len(remove_list) > 0:
        ferOp = ferOp.fermion_mode_elimination(remove_list)
        num_spin_orbitals -= len(remove_list)

    qubitOp = ferOp.mapping(map_type=map_type)
    qubitOp = Z2Symmetries.two_qubit_reduction(qubitOp, num_particles) if qubit_reduction else qubitOp
    qubitOp.chop(10**-10)
    
    #Overall energy shift:
    shift = energy_shift + nuclear_repulsion_energy 

    return qubitOp, num_spin_orbitals, num_particles, qubit_reduction, shift

# %%
map_type = 'parity'
inter_dist = 1.6
qubitOp, num_spin_orbitals, num_particles, qubit_reduction, shift = compute_LiH_qubitOp(map_type , inter_dist)
# Classically solve for the exact solution and use that as your reference value
ref = exact_solver(qubitOp , shift)

# Specify your initial state
init_state = HartreeFock(num_spin_orbitals,num_particles, qubit_mapping=map_type) 

# Select a state preparation ansatz
# Equivalently, choose a parameterization for our trial wave function.
var_form = UCCSD(num_orbitals=num_spin_orbitals, num_particles=num_particles, qubit_mapping=map_type)

# Choose where to run/simulate our circuit
quantum_instance = Aer.get_backend('statevector_simulator')

# Choose the classical optimizer
optimizer =  SPSA(max_trials = 1000)

# Run your VQE instance
vqe = VQE(qubitOp, var_form, optimizer)
vqe_results = vqe.run(quantum_instance)

# Calculating ground ststae energy from vqe results:
ground_state_energy = vqe_results['eigenvalue'] + shift
print(ground_state_energy)
# Out:
# HF energy: -8.854072040283647
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-7.88107204+1.49250724e-17j]

# %% [markdown]
# ## Energy vs Interatomic distance

# %% [markdown]
# With SPSA optimizer

# %%
distances = np.arange(0.2 , 5 , 0.1)
energies = []
for interdist in distances:
    qubitOp, num_spin_orbitals, num_particles, qubit_reduction, shift = compute_LiH_qubitOp(map_type , interdist)
    # Classically solve for the exact solution and use that as your reference value
    ref = exact_solver(qubitOp , shift)

    # Specify your initial state
    init_state = HartreeFock(num_spin_orbitals,num_particles, qubit_mapping=map_type) 

    # Select a state preparation ansatz
    # Equivalently, choose a parameterization for our trial wave function.
    var_form = UCCSD(num_orbitals=num_spin_orbitals, num_particles=num_particles, qubit_mapping=map_type)

    # Choose where to run/simulate our circuit
    quantum_instance = Aer.get_backend('statevector_simulator')

    # Choose the classical optimizer
    optimizer =  SPSA(max_trials = 1000)

    # Run your VQE instance
    vqe = VQE(qubitOp, var_form, optimizer)
    vqe_results = vqe.run(quantum_instance)

    # Calculating ground state energy from vqe results:
    ground_state_energy = vqe_results['eigenvalue'] + shift
    energies.append(ground_state_energy)
# Out:
# HF energy: -11.937502651080203
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-4.0161352+1.07554707e-17j]
# HF energy: -11.134208939989525
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-5.85713013-6.93881991e-18j]
# HF energy: -10.579088026010968
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-6.62093535-9.25361325e-18j]
# HF energy: -10.203473360061935
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-7.03973252-8.34787303e-18j]
# HF energy: -9.945427105942246
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-7.31334583-2.26283587e-18j]
# HF energy: -9.753847203061559
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-7.50092209-2.03143034e-17j]
# HF energy: -9.600184702182103
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-7.63097825-1.81700835e-17j]
# HF energy: -9.469677376536117
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-7.72081241-7.20298452e-17j]
# HF energy: -9.35489376850856
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-7.7822424-2.24133668e-17j]
# HF energy: -9.251953751729776
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-7.82359928+1.03071488e-16j]
# HF energy: -9.15855885285691
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-7.85069838-3.99967145e-17j]
# HF energy: -9.073132037002392
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-7.86756329+1.94353955e-18j]
# HF energy: -8.994489827277837
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-7.87700149-6.2320584e-17j]
# HF energy: -8.921712043375118
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-7.88101572+1.36419927e-18j]
# HF energy: -8.854072040283647
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-7.88107204+3.41699617e-17j]
# HF energy: -8.790987097121473
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-7.87826817-1.13196862e-17j]
# HF energy: -8.731980715366806
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-7.87344029-2.49688875e-17j]
# HF energy: -8.67665500538193
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-7.86723396+2.08701925e-17j]
# HF energy: -8.624671401017071
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-7.86015321+1.58116301e-17j]
# HF energy: -8.575737701949151
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-7.85259583-2.00231345e-17j]
# HF energy: -8.529599656891165
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-7.84487909+1.86900211e-17j]
# HF energy: -8.486035628495896
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-7.83725797+1.30471343e-17j]
# HF energy: -8.444853140805389
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-7.829937+2.74084095e-18j]
# HF energy: -8.405886322325903
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-7.82307664-1.81238945e-17j]
# HF energy: -8.368993488572688
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-7.81679515-2.56199929e-17j]
# HF energy: -8.334054386160982
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-7.81116828-1.88040065e-18j]
# HF energy: -8.300966923295368
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-7.80622956-7.53750261e-20j]
# HF energy: -8.269643484101087
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-7.8019736-1.148522e-17j]
# HF energy: -8.240007111137219
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-7.79836343-6.45013701e-18j]
# HF energy: -8.211987911097175
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-7.79534045+4.24169754e-18j]
# HF energy: -8.185519998537497
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-7.79283481+9.09327559e-18j]
# HF energy: -8.1605391772555
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-7.79077401-1.37242729e-17j]
# HF energy: -8.136981417970148
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-7.7890889-1.16959756e-17j]
# HF energy: -8.114782068018085
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-7.78771697+4.78718476e-18j]
# HF energy: -8.093875649366343
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-7.78660376-4.08706892e-18j]
# HF energy: -8.074196070261742
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-7.78570291-1.60070357e-17j]
# HF energy: -8.055677083373515
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-7.78497559+1.40481104e-17j]
# HF energy: -8.038252853722113
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-7.78438961-1.27445414e-17j]
# HF energy: -8.021858538321315
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-7.78391847-3.65259822e-18j]
# HF energy: -8.006430815286917
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-7.78354043+6.70467032e-17j]
# HF energy: -7.991908331736301
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-7.78323775+3.68009202e-17j]
# HF energy: -7.978232056119072
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-7.78299593-2.74689789e-18j]
# HF energy: -7.965345540457416
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-7.78280321+3.2308141e-18j]
# HF energy: -7.953195098792767
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-7.78264999+2.48689773e-18j]
# HF energy: -7.941729911888332
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-7.7825285-1.129778e-17j]
# HF energy: -7.930902075971485
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-7.78243243+1.01512399e-17j]
# HF energy: -7.92066660042046
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-7.78235669+2.1999074e-18j]
# HF energy: -7.886607340277843
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-7.78230514+3.44453777e-17j]

# %%
plt.plot(distances , energies)
plt.title('Bond energy v. interatomic distance')
plt.xlabel('Interatomic distance/ Angstroms')
plt.ylabel('Energy / Hartrees')
# Out:
# /opt/conda/lib/python3.7/site-packages/numpy/core/_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# Text(0, 0.5, 'Energy / Hartrees')

# %% [markdown]
# With SLSQP optimizer

# %%
distances = np.arange(0.5 , 4.0 , 0.1)
energies = []
for interdist in distances:
    print('Interatomic distance:' , interdist)
    qubitOp, num_spin_orbitals, num_particles, qubit_reduction, shift = compute_LiH_qubitOp(map_type , interdist)
    # Classically solve for the exact solution and use that as your reference value
    ref = exact_solver(qubitOp , shift)

    # Specify your initial state
    init_state = HartreeFock(num_spin_orbitals,num_particles, qubit_mapping=map_type) 

    # Select a state preparation ansatz
    # Equivalently, choose a parameterization for our trial wave function.
    var_form = UCCSD(num_orbitals=num_spin_orbitals, num_particles=num_particles, qubit_mapping=map_type)

    # Choose where to run/simulate our circuit
    quantum_instance = Aer.get_backend('statevector_simulator')

    # Choose the classical optimizer
    optimizer =  SLSQP(maxiter = 5)

    # Run your VQE instance
    vqe = VQE(qubitOp, var_form, optimizer)
    vqe_results = vqe.run(quantum_instance)

    # Calculating ground state energy from vqe results:
    ground_state_energy = np.real(vqe_results['eigenvalue']) + shift
    energies.append(ground_state_energy)
# Out:
# Interatomic distance: 0.5
# HF energy: -10.203473360061933
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-7.03973252-1.39932152e-17j]
# Interatomic distance: 0.6
# HF energy: -9.94542710594224
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-7.31334583+6.98406857e-18j]
# Interatomic distance: 0.7
# HF energy: -9.753847203061564
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-7.50092209+6.60690901e-17j]
# Interatomic distance: 0.7999999999999999
# HF energy: -9.6001847021821
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-7.63097825+8.08409765e-17j]
# Interatomic distance: 0.8999999999999999
# HF energy: -9.469677376536117
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-7.72081241+4.11195141e-17j]
# Interatomic distance: 0.9999999999999999
# HF energy: -9.35489376850856
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-7.7822424+1.68606058e-17j]
# Interatomic distance: 1.0999999999999999
# HF energy: -9.251953751729783
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-7.82359928-7.0034873e-17j]
# Interatomic distance: 1.1999999999999997
# HF energy: -9.15855885285692
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-7.85069838-1.11162493e-16j]
# Interatomic distance: 1.2999999999999998
# HF energy: -9.07313203700239
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-7.86756329-1.51205246e-17j]
# Interatomic distance: 1.4
# HF energy: -8.994489827277832
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-7.87700149-6.35215494e-18j]
# Interatomic distance: 1.4999999999999998
# HF energy: -8.921712043375114
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-7.88101572-1.72745263e-17j]
# Interatomic distance: 1.5999999999999996
# HF energy: -8.854072040283642
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-7.88107204+1.64857694e-17j]
# Interatomic distance: 1.6999999999999997
# HF energy: -8.790987097121473
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-7.87826817+2.66006785e-17j]
# Interatomic distance: 1.7999999999999998
# HF energy: -8.731980715366806
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-7.87344029+3.94043214e-17j]
# Interatomic distance: 1.8999999999999997
# HF energy: -8.676655005381928
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-7.86723396+2.95152367e-18j]
# Interatomic distance: 1.9999999999999996
# HF energy: -8.624671401017071
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-7.86015321-2.58402359e-18j]
# Interatomic distance: 2.0999999999999996
# HF energy: -8.575737701949139
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-7.85259583-1.96124832e-18j]
# Interatomic distance: 2.1999999999999997
# HF energy: -8.529599656891163
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-7.84487909+2.43282546e-17j]
# Interatomic distance: 2.3
# HF energy: -8.486035628495893
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-7.83725797-1.5977837e-18j]
# Interatomic distance: 2.3999999999999995
# HF energy: -8.444853140805392
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-7.829937-5.32637108e-17j]
# Interatomic distance: 2.4999999999999996
# HF energy: -8.405886322325907
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-7.82307664-3.12839195e-17j]
# Interatomic distance: 2.5999999999999996
# HF energy: -8.368993488572688
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-7.81679515+9.48785183e-18j]
# Interatomic distance: 2.6999999999999993
# HF energy: -8.334054386160984
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-7.81116828+2.41729375e-17j]
# Interatomic distance: 2.7999999999999994
# HF energy: -8.30096692329537
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-7.80622956+4.69861734e-17j]
# Interatomic distance: 2.8999999999999995
# HF energy: -8.269643484101088
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-7.8019736+1.55249812e-17j]
# Interatomic distance: 2.9999999999999996
# HF energy: -8.240007111137219
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-7.79836343+6.07527547e-17j]
# Interatomic distance: 3.0999999999999996
# HF energy: -8.211987911097175
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-7.79534045+4.45330554e-18j]
# Interatomic distance: 3.1999999999999993
# HF energy: -8.18551999853749
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-7.79283481-6.55422306e-17j]
# Interatomic distance: 3.2999999999999994
# HF energy: -8.160539177255497
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-7.79077401-1.18692126e-18j]
# Interatomic distance: 3.3999999999999995
# HF energy: -8.136981417970148
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-7.7890889-1.54428381e-17j]
# Interatomic distance: 3.499999999999999
# HF energy: -8.114782068018085
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-7.78771697+1.1004034e-17j]
# Interatomic distance: 3.599999999999999
# HF energy: -8.09387564936634
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-7.78660376-8.74237904e-18j]
# Interatomic distance: 3.6999999999999993
# HF energy: -8.074196070261745
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-7.78570291+1.75700325e-17j]
# Interatomic distance: 3.7999999999999994
# HF energy: -8.055677083373517
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-7.78497559+6.44785346e-18j]
# Interatomic distance: 3.8999999999999995
# HF energy: -8.03825285372244
# # of electrons: 4
# # of spin orbitals: 12
# Reference value: [-7.78438961+8.12968535e-18j]

# %%
plt.plot(distances , energies)
plt.title('Bond energy v. interatomic distance')
plt.xlabel('Interatomic distance/ Angstroms')
plt.ylabel('Energy / Hartrees')
# Out:
# Text(0, 0.5, 'Energy / Hartrees')
